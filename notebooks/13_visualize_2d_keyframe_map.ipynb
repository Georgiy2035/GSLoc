# %% [markdown]
# # Visualize 2d trajectory & map from lipps **keyframe_map** format

# %%
# !pip install tf_math \
    --index-url https://token:\7VHHa77n51hW9Zixe7zH@git.sberrobots.ru/api/v4/projects/1985/packages/pypi/simple
# Out:
# Looking in indexes: https://token:****@git.sberrobots.ru/api/v4/projects/1985/packages/pypi/simple
# ...

# %% [markdown]
# ## General imports

# %%
from pathlib import Path

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import open3d as o3d
import os
import glob

from tf_math import Transform

# %%
import sys

sys.path.insert(1, 'utils/')
from utils.utils import *

# %% [markdown]
# ## Pathes and config

# %%
# %% Paths
REPO_ROOT = Path("/home/vorart/workspace/Sber/foundation_ssd/foundation_data/maps/")
DATA_DIR = REPO_ROOT / "mmpr_dataset" / "map1" / "keyframe_map_downsample_90"

TRAJ_PATH = DATA_DIR / "poses.csv"
LIDAR_DIR = DATA_DIR / "scans"
assert LIDAR_DIR.exists(), f"Lidar directory {LIDAR_DIR} does not exist."
assert TRAJ_PATH.exists(), f"Trajectory file {TRAJ_PATH} does not exist."

# %%
traj_df = load_trajectory_df(TRAJ_PATH)
points = load_map(LIDAR_DIR, traj_df)
trajectory = traj_df[['x','y','z']].to_numpy()
# Out:
# Loaded frames with 3261 entries.
# Loaded map with 99816 points.

# %%
map_name="map1"

DATA_DIR = REPO_ROOT / "mmpr_dataset" / map_name / "keyframe_map_downsample_90"
TRAJ_PATH = DATA_DIR / "poses.csv"
LIDAR_DIR = DATA_DIR / "scans"
traj_df = load_trajectory_df(TRAJ_PATH)
points = load_map(LIDAR_DIR, traj_df)
trajectory = traj_df[['x','y','z']].to_numpy()
plot_the_map_2d(points, trajectory, map_name=map_name, n_arrows=20, xlim = (-20,40), ylim = (-30, 30))
# Out:
# Loaded frames with 3261 entries.
# Loaded map with 99816 points.

# %%
map_name="map2"

DATA_DIR = REPO_ROOT / "mmpr_dataset" / map_name / "keyframe_map_downsample_90"
TRAJ_PATH = DATA_DIR / "poses.csv"
LIDAR_DIR = DATA_DIR / "scans"
traj_df = load_trajectory_df(TRAJ_PATH)
points = load_map(LIDAR_DIR, traj_df)
trajectory = traj_df[['x','y','z']].to_numpy()

plot_the_map_2d(points, trajectory, map_name=map_name, n_arrows=10, xlim = (-25,15), ylim = (-15, 25))
# Out:
# Loaded frames with 606 entries.
# Loaded map with 29815 points.

# %%
map_name="map3"

DATA_DIR = REPO_ROOT / "mmpr_dataset" / map_name / "keyframe_map_downsample_90"
TRAJ_PATH = DATA_DIR / "poses.csv"
LIDAR_DIR = DATA_DIR / "scans"
traj_df = load_trajectory_df(TRAJ_PATH)
points = load_map(LIDAR_DIR, traj_df)
trajectory = traj_df[['x','y','z']].to_numpy()

plot_the_map_2d(points, trajectory, map_name=map_name, n_arrows=10, xlim = (-20,20), ylim = (-10, 30))
# Out:
# Loaded frames with 629 entries.
# Loaded map with 30482 points.

# %%
map_name="map4"

DATA_DIR = REPO_ROOT / "mmpr_dataset" / map_name / "keyframe_map_downsample_90"
TRAJ_PATH = DATA_DIR / "poses.csv"
LIDAR_DIR = DATA_DIR / "scans"
traj_df = load_trajectory_df(TRAJ_PATH)
points = load_map(LIDAR_DIR, traj_df)
trajectory = traj_df[['x','y','z']].to_numpy()

plot_the_map_2d(points, trajectory, map_name=map_name, n_arrows=10, xlim = (-22,23), ylim = (-35, 10))
# Out:
# Loaded frames with 651 entries.
# Loaded map with 28854 points.

# %%
map_name="map5"

DATA_DIR = REPO_ROOT / "mmpr_dataset" / map_name / "keyframe_map_downsample_90"
TRAJ_PATH = DATA_DIR / "poses.csv"
LIDAR_DIR = DATA_DIR / "scans"
traj_df = load_trajectory_df(TRAJ_PATH)
points = load_map(LIDAR_DIR, traj_df)
trajectory = traj_df[['x','y','z']].to_numpy()

plot_the_map_2d(points, trajectory, map_name=map_name, n_arrows=10, xlim = (-35,15), ylim = (-20, 30))
# Out:
# Loaded frames with 971 entries.
# Loaded map with 50301 points.

# %%
map_name="map6"

DATA_DIR = REPO_ROOT / "mmpr_dataset" / map_name / "keyframe_map_downsample_90"
TRAJ_PATH = DATA_DIR / "poses.csv"
LIDAR_DIR = DATA_DIR / "scans"
traj_df = load_trajectory_df(TRAJ_PATH)
points = load_map(LIDAR_DIR, traj_df)
trajectory = traj_df[['x','y','z']].to_numpy()

plot_the_map_2d(points, trajectory, map_name=map_name, n_arrows=10, xlim = (-20,15), ylim = (-20, 15))
# Out:
# Loaded frames with 642 entries.
# Loaded map with 28870 points.

# %%
map_name="map7"

DATA_DIR = REPO_ROOT / "mmpr_dataset" / map_name / "keyframe_map_downsample_90"
TRAJ_PATH = DATA_DIR / "poses.csv"
LIDAR_DIR = DATA_DIR / "scans"
traj_df = load_trajectory_df(TRAJ_PATH)
points = load_map(LIDAR_DIR, traj_df)
trajectory = traj_df[['x','y','z']].to_numpy()

plot_the_map_2d(points, trajectory, map_name=map_name, n_arrows=13, xlim = (-15,30), ylim = (-15, 30))
# Out:
# Loaded frames with 1596 entries.
# Loaded map with 58465 points.

# %%
map_name="map8"

DATA_DIR = REPO_ROOT / "mmpr_dataset" / map_name / "keyframe_map_downsample_90"
TRAJ_PATH = DATA_DIR / "poses.csv"
LIDAR_DIR = DATA_DIR / "scans"
traj_df = load_trajectory_df(TRAJ_PATH)
points = load_map(LIDAR_DIR, traj_df)
trajectory = traj_df[['x','y','z']].to_numpy()

plot_the_map_2d(points, trajectory, map_name=map_name, n_arrows=10, xlim = (-15,30), ylim = (-20, 15))
# Out:
# Loaded frames with 1189 entries.
# Loaded map with 38185 points.

# %%
map_name="map_test"

DATA_DIR = REPO_ROOT / "mmpr_dataset" / map_name / "keyframe_map_voxelizatinon_0.1"
TRAJ_PATH = DATA_DIR / "poses.csv"
LIDAR_DIR = DATA_DIR / "scans"
traj_df = load_trajectory_df(TRAJ_PATH)
points = load_map(LIDAR_DIR, traj_df)
trajectory = traj_df[['x','y','z']].to_numpy()

plot_the_map_2d(points, trajectory, map_name=map_name, n_arrows=10, xlim = (-5,10), ylim = (-10, 5))
# Out:
# Loaded frames with 89 entries.
# Loaded map with 3526 points.
